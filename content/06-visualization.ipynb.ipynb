# %% [markdown]
# # Using Matplotlib and Seaborn for EDA
# #### In EDA, these libraries help uncover patterns, trends, and anomalies through visual representation

# %% [markdown]
# # Data Preparation: Load and clean your dataset using pandas.

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/Abduttayyeb/Visual-Data-Analysis/master/Graph_Data.csv')
data.head(3)
# Out:
#           Name  Gender  Age  Siblings PassType    Fare  Survived
# 0  Harry Jacob    Male   22         1   Silver  230.55         0
# 1   Laura Gray  Female   38         1  Regular  130.45         0
# 2  Laina Henry  Female   26         0  Regular  100.25         0

# %% [markdown]
# # Univariate Analysis: Analyze individual variables to understand their distribution.

# %% [markdown]
# ## Histogram with Matplotlib:

# %%
import matplotlib.pyplot as plt
plt.hist(data['Age'], bins=10)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Age')
plt.show()

# %% [markdown]
# ## KDE Plot with Seaborn:

# %%
import seaborn as sns
sns.kdeplot(data['Age'], fill=True)
plt.title('KDE Plot of Age')
plt.show()

# %% [markdown]
# ## Boxplots with Seaborn

# %%
sns.boxplot(data['Age']);

# %% [markdown]
# # Bivariate Analysis: Examine relationships between two variables.

# %% [markdown]
# ## Scatter Plot with Matplotlib:

# %%
plt.figure(figsize=(7,7))
plt.scatter(data['Age'], data['Fare'])
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Scatter Plot between Age and Fare')
plt.show()

# %% [markdown]
# ## Joint Plot with Seaborn:

# %%
sns.jointplot(x='Age', y='Fare', data=data, kind='scatter')
plt.figure(figsize=(12,12))
plt.show()

# %% [markdown]
# # Multivariate Analysis: Explore interactions among multiple variables.

# %% [markdown]
# ## Pair Plot with Seaborn:

# %%
sns.pairplot(data)
plt.show()

# %% [markdown]
# ## Heatmap of Correlation Matrix:

# %%
from sklearn.preprocessing import OrdinalEncoder
data1=data.copy()
data1[data.select_dtypes(include='object').columns]=OrdinalEncoder().fit_transform(data[data.select_dtypes(include='object').columns])
correlation = data1.corr()
sns.heatmap(correlation, annot=True,)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# # some More Plots

# %% [markdown]
# ## Bar Plot

# %%
plt.figure(figsize = (5,5))
sns.countplot(x='Gender',data=data, label = 'Count')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# ## Pie plot

# %%
values = [20, 55, 5, 17, 3]
colors = ['g', 'r', 'y', 'b', 'm']
labels = ["Apple", "Google", "T", "TSLA", "AMZN"]
explode = [0, 0.2, 0, 0, 0.2]
# Use matplotlib to plot a pie chart 
plt.figure(figsize = (5, 5))
plt.pie(values, labels = labels,explode=explode)
plt.title('Stock Portfolio')
# Out:
# Text(0.5, 1.0, 'Stock Portfolio')

# %%
plt.bar(data['Gender'].unique(),data['Gender'].value_counts())
# Out:
# <BarContainer object of 2 artists>

# %%
plt.plot(data['Age'])

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,2)
plt.bar(data['Gender'].unique(),data['Gender'].value_counts());

plt.subplot(2,2,1)
plt.plot(data['Age']);

values = [20, 55, 5, 17, 3]
labels = ["Apple", "Google", "T", "TSLA", "AMZN"]

plt.subplot(2,2,3)
plt.title('Stock Portfolio')
plt.pie(values, labels = labels);

# %%
fig,ax=plt.subplots(2,2,figsize=(20,10))


ax[0,0].bar(data['Gender'].unique(),data['Gender'].value_counts());

ax[0,1].plot(data['Age']);

ax[1,0].pie(data['Siblings'].value_counts(),labels=data['Siblings'].unique());
ax[1,0].set_title('Stock Portfolio')
ax[0,1].set_title('line plot')
ax[0,0].set_title('bar plot')
ax[1,1].set_title('Empty plot')
# Out:
# Text(0.5, 1.0, 'Empty plot')
